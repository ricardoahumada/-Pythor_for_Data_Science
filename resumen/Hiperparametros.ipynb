# %% [markdown]
# # Hiperparámetros comunes

# %% [markdown]
# <table class="MsoNormalTable" style="width: 538.0pt; border-collapse: collapse;" border="0" cellspacing="0" cellpadding="0">
# <tbody>
# <tr style="height: 18.6pt;">
# <td style="width: 134.0pt; border: solid #4472C4 1.0pt; border-right: none; background: #4472C4; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><strong><span style="font-size: 14.0pt; color: white;">Algoritmo</span></strong></p>
# </td>
# <td style="width: 123.0pt; border-top: solid #4472C4 1.0pt; border-left: none; border-bottom: solid #4472C4 1.0pt; border-right: none; background: #4472C4; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><strong><span style="font-size: 14.0pt; color: white;">Hiperpar&aacute;metros</span></strong></p>
# </td>
# <td style="width: 145.0pt; border-top: solid #4472C4 1.0pt; border-left: none; border-bottom: solid #4472C4 1.0pt; border-right: none; background: #4472C4; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><strong><span style="font-size: 14.0pt; color: white;">Valor por defecto</span></strong></p>
# </td>
# <td style="width: 136.0pt; border: solid #4472C4 1.0pt; border-left: none; background: #4472C4; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><strong><span style="font-size: 14.0pt; color: white;">Notas</span></strong></p>
# </td>
# </tr>
# <tr style="height: 14.7pt;">
# <td style="width: 134.0pt; border: solid #8EAADB 1.0pt; border-top: none; background: #D9E2F3; padding: 2.85pt 5.4pt 2.85pt 5.4pt;" rowspan="4">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><strong><span style="color: black;">KNN</span></strong></p>
# </td>
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #D9E2F3; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">N_neighbors (K)</span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #D9E2F3; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">5</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #D9E2F3; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Tiende a ser impar</span></p>
# </td>
# </tr>
# <tr style="height: 14.7pt;">
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #D9E2F3; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Leaf_size </span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #D9E2F3; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">30</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #D9E2F3; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">&nbsp;</span></p>
# </td>
# </tr>
# <tr style="height: 14.7pt;">
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #D9E2F3; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Weights </span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #D9E2F3; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">&ldquo;Uniform&rdquo;</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #D9E2F3; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">&nbsp;</span></p>
# </td>
# </tr>
# <tr style="height: 14.7pt;">
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #D9E2F3; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Metric&nbsp;</span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #D9E2F3; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">&ldquo;minkowski&rdquo; con p=2,</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #D9E2F3; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">&nbsp;</span></p>
# </td>
# </tr>
# <tr style="height: 14.4pt;">
# <td style="width: 134.0pt; border-top: none; border-left: solid #8EAADB 1.0pt; border-bottom: none; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;" rowspan="5">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><strong><span style="color: black;">Decision Trees y Random Forests</span></strong></p>
# </td>
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">N_estimators </span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">100</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Solo en RandomForest</span></p>
# </td>
# </tr>
# <tr style="height: 14.7pt;">
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Max_depth </span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">None</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">&nbsp;</span></p>
# </td>
# </tr>
# <tr style="height: 14.7pt;">
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Min_samples_split </span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">2</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">&nbsp;</span></p>
# </td>
# </tr>
# <tr style="height: 14.7pt;">
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Min_samples_leaf </span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">1</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">&nbsp;</span></p>
# </td>
# </tr>
# <tr style="height: 14.7pt;">
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Criterion </span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">&ldquo;gini&rdquo;</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #ACB9CA; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">&nbsp;</span></p>
# </td>
# </tr>
# <tr style="height: 14.4pt;">
# <td style="width: 134.0pt; border: solid #8EAADB 1.0pt; border-bottom: none; background: #F4B084; padding: 2.85pt 5.4pt 2.85pt 5.4pt;" rowspan="3">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><strong><span style="color: black;">AdaBoost y Gradient Boosting</span></strong></p>
# </td>
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #F4B084; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">N_estimators </span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #F4B084; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">50</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #F4B084; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Compensaci&oacute;n sesgo-varianza: cuanto mayor sea el n&uacute;mero de estimadores, menor ser&aacute; el sesgo.</span></p>
# </td>
# </tr>
# <tr style="height: 14.7pt;">
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #F4B084; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Learning_rate </span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #F4B084; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">0.1</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #F4B084; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">&nbsp;</span></p>
# </td>
# </tr>
# <tr style="height: 43.5pt;">
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #F4B084; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Base_estimator (AdaBoost) / Loss (Gradient Boosting) </span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #F4B084; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">None/"deviance"</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #F4B084; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">&nbsp;</span></p>
# </td>
# </tr>
# <tr style="height: 14.4pt;">
# <td style="width: 134.0pt; border: solid #8EAADB 1.0pt; border-bottom: none; background: #FFD966; padding: 2.85pt 5.4pt 2.85pt 5.4pt;" rowspan="3">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><strong><span style="color: black;">Support Vector Machines (SVM)</span></strong></p>
# </td>
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #FFD966; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">C</span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #FFD966; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">1.0</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #FFD966; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Compensaci&oacute;n sesgo-varianza: un valor C m&aacute;s bajo permite m&aacute;s errores, lo que se traduce en un sesgo m&aacute;s alto.</span></p>
# </td>
# </tr>
# <tr style="height: 14.7pt;">
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #FFD966; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Gamma</span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #FFD966; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">"scale"</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #FFD966; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">&nbsp;</span></p>
# </td>
# </tr>
# <tr style="height: 14.7pt;">
# <td style="width: 123.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #FFD966; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">Kernel </span></p>
# </td>
# <td style="width: 145.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #FFD966; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; text-align: center; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">"rbf"</span></p>
# </td>
# <td style="width: 136.0pt; border-top: none; border-left: none; border-bottom: solid #8EAADB 1.0pt; border-right: solid #8EAADB 1.0pt; background: #FFD966; padding: 2.85pt 5.4pt 2.85pt 5.4pt;">
# <p style="margin: 0cm; line-height: normal; font-size: 11pt; font-family: Calibri, sans-serif;"><span style="color: black;">&nbsp;</span></p>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Scikit-learn: ajuste de hiperparámetros con búsqueda en cuadrícula y búsqueda aleatoria
#
# Los dos métodos de hiperparámetros que se usaran con más frecuencia son una búsqueda en cuadrícula y una búsqueda aleatoria.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Cómo tunear hiperparámentros:
# https://scikit-learn.org/stable/modules/grid_search.html
